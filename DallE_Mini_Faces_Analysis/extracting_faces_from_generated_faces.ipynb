# %%
#mount drive

# %%
project_dir = "/content/drive/MyDrive/adv_ml_project_vt"
extracted_faces_dir = project_dir + "/extracted_faces"

# %% [markdown]
# ## Install stuff

# %%
# install all packages
# !pip install keras
# !pip install tensorflow
from keras.models import load_model
# !pip install mtcnn
# confirm mtcnn was installed correctly
import mtcnn
# print version
print(mtcnn.__version__)

import numpy as np
from mtcnn.mtcnn import MTCNN
from numpy import asarray
from PIL import Image
import matplotlib.pyplot as plt


# Simple python package to shut up Tensorflow warnings and logs.
# !pip install silence_tensorflow
import silence_tensorflow.auto

# %%
# extract a single face from a given photograph
def extract_face(filename, index, required_size=(250, 250)):
    # load image from file
    image = Image.open(filename)
    # convert to RGB, if needed
    image = image.convert('RGB')
    # convert to array
    pixels = np.asarray(image)
    # create the detector, using default weights
    detector = MTCNN()
    # detect faces in the image
    results = detector.detect_faces(pixels)
    # extract the bounding box from the first face
    if len(results) >=1:
        x1, y1, width, height = results[0]['box']
        if height-width>=15:
            # bug fix
            x1, y1 = abs(x1), abs(y1)
            x2, y2 = x1 + width, y1 + height
            # extract the face
            face = pixels[y1:y2, x1:x2]
            # resize pixels to the model size
            image = Image.fromarray(face)
            image = image.resize(required_size)
            face_array = np.asarray(image)
            plt.imsave(os.path.join(extracted_faces_dir, 'dalle_mini_extracted_face_img_{}.jpg'.format(index)),face_array)
            return True
    return False

# %%
import os
files = os.listdir(project_dir + "/generated_images")

# %%
len(files)
# Out:
# 1100

# %%
files[:5]
# Out:
# ['dalle_mini_face_img_388.jpg',
#  'dalle_mini_face_img_389.jpg',
#  'dalle_mini_face_img_382.jpg',
#  'dalle_mini_face_img_387.jpg',
#  'dalle_mini_face_img_384.jpg']

# %%
index =0
for file in files:
    if extract_face(os.path.join(project_dir + "/generated_images", file), index = index):
        print(f'Found face for image: {file}')
        index+=1
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# 1/1 [==============================] - 0s 124ms/step
# Found face for image: dalle_mini_face_img_609.jpg
# ...
# 1/1 [==============================] - 0s 140ms/step
# Found face for image: dalle_mini_face_img_620.jpg
# ...
# 1/1 [==============================] - 0s 107ms/step
# Found face for image: dalle_mini_face_img_623.jpg
# ...
# 1/1 [==============================] - 0s 107ms/step
# Found face for image: dalle_mini_face_img_629.jpg
# ...
# 1/1 [==============================] - 0s 109ms/step
# Found face for image: dalle_mini_face_img_631.jpg
# ...
# 1/1 [==============================] - 0s 109ms/step
# Found face for image: dalle_mini_face_img_633.jpg
# ...
# 1/1 [==============================] - 0s 110ms/step
# Found face for image: dalle_mini_face_img_635.jpg
# ...
# 1/1 [==============================] - 0s 112ms/step
# Found face for image: dalle_mini_face_img_632.jpg
# ...
# 1/1 [==============================] - 0s 113ms/step
# ...
