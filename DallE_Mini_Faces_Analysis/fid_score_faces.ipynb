# %%
# !pip install pytorch-fid
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for pytorch-fid: filename=pytorch_fid-0.2.1-py3-none-any.whl size=14834 sha256=b44d98e8c64f849725e396a353affc6c16fdc93123a22ac5d536b8b429419216
#   Stored in directory: /root/.cache/pip/wheels/24/ac/03/c5634775c8a64f702343ef5923278f8d3bb8c651debc4a6890
# Successfully built pytorch-fid
# ...

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#!git clone https://github.com/XiaonaZhou/Text_to_Image_analysis.git
# Out:
# Cloning into 'Text_to_Image_analysis'...
# remote: Enumerating objects: 89241, done.
# remote: Counting objects: 100% (2255/2255), done.
# remote: Compressing objects: 100% (2233/2233), done.
# remote: Total 89241 (delta 29), reused 2248 (delta 22), pack-reused 86986
# Receiving objects: 100% (89241/89241), 3.30 GiB | 16.44 MiB/s, done.
# Resolving deltas: 100% (265/265), done.
# Checking out files: 100% (86043/86043), done.

# %%
"""import os
import cv2
import numpy as np
import shutil
np.random.seed(5824)

paths = {'real': ('/content/Text_to_Image_analysis/extracted_faces_from_COCO', 'FID_real_face/'), 
         'generated': ('/content/drive/MyDrive/adv_ml_project_vt/extracted_faces', 'FID_generated_face/')}

# res = {}
num_imgs = 5000
for k in range(10):
    print(k)
    for f in ['real', 'generated']: #range(2):
        img_path, save_path = paths[f]
        files = os.listdir(img_path)
        print(img_path)
        print(save_path)
        np.random.shuffle(files)

        #if os.path.exists(save_path):
        #    shutil.rmtree(save_path)    
        #os.mkdir(save_path)

        #print(save_path)

        count = 0
        while count < num_imgs:
            for f_name in files:
                image = cv2.imread(os.path.join(img_path,f_name))
                cv2.imwrite(os.path.join(save_path, 'face_img_{}.jpg'.format(count)), image)

                count += 1
                #print(count)
                if count >= num_imgs: break     

    #!python -m pytorch_fid FID_real_face/ FID_generated_face/ --device cuda:0
    break """
# Out:
# 0
# /content/Text_to_Image_analysis/extracted_faces_from_COCO
# FID_real_face/
# /content/drive/MyDrive/adv_ml_project_vt/extracted_faces
# FID_generated_face/

# %%
# !python -m pytorch_fid /content/drive/MyDrive/adv_ml_project_vt/extracted_eyes_from_coco /content/drive/MyDrive/adv_ml_project_vt/extracted_eyes_from_extracted_faces --device cuda:0
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:01<00:00, 76.7MB/s]
# 100% 52/52 [00:46<00:00,  1.13it/s]
# 100% 3/3 [00:01<00:00,  2.60it/s]
# FID:  112.2383969537029
